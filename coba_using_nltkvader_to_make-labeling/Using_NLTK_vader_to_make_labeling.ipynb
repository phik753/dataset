# %% [markdown]
# <a href="https://colab.research.google.com/github/adamazanos/using_nltkvader_to_make-labeling/blob/main/Using_NLTK_vader_to_make_labeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The objective of this project is to label data using instructions from
#
#  https://thecleverprogrammer.com/2021/11/24/add-labels-to-a-dataset-for-sentiment-analysis/.
#
# In this project, we will use the NLTK Vader library to calculate the compound score.

# %% [markdown]
# #01. Download the library and import the data

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download("vader_lexicon")
import pandas as pd
data = pd.read_excel("https://raw.githubusercontent.com/phik753/dataset/master/merge_11_cabang.xlsx")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...

# %% [markdown]
# # Translate dataset

# %%
# Import library
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd
from googletrans import Translator  # Library untuk menerjemahkan teks

# Download VADER lexicon
nltk.download("vader_lexicon")

# Load dataset
data = pd.read_excel("https://raw.githubusercontent.com/phik753/dataset/master/merge_11_cabang.xlsx")
data = data.dropna()  # Hapus baris dengan nilai kosong
print("Dataset awal:")
print(data.head())

# Terjemahkan kolom teks ke Bahasa Inggris
translator = Translator()

# Fungsi untuk menerjemahkan teks
def translate_text(text):
    try:
        return translator.translate(text, src="id", dest="en").text
    except Exception as e:
        print(f"Error saat menerjemahkan: {text}, {e}")
        return text

# Lakukan terjemahan untuk setiap baris di kolom teks (misal kolom bernama "snippet")
data["snippet_en"] = data["snippet"].apply(translate_text)
print("Dataset setelah terjemahan:")
print(data[["snippet", "snippet_en"]].head())
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ACER\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Dataset awal:
#          Source.Name           user_name  rating  \
# 0  reviews_bogo.xlsx       Lucky Rivanto       5
# 1  reviews_bogo.xlsx  Novita Catur putri       5
# 2  reviews_bogo.xlsx       aditiya risky       5
# 3  reviews_bogo.xlsx          Fita Julia       5
# 4  reviews_bogo.xlsx      M.choirul arif       5
#
#                                              snippet          date  \
# 0                                                 Ok  7 months ago
# 1                                             Nice 🤗   2 years ago
# 2                              very friendly service   2 years ago
# 3                                        Very good♥️   2 years ago
# 4  Harga lmyan terjangkau, tempatnya bersih ada p...  6 months ago
#
#              iso_date iso_date_of_last_edit
# 0 2024-03-18 09:57:31   2024-03-18 09:57:31
# 1 2022-07-07 11:04:13   2022-07-07 11:04:13
# 2 2022-09-25 20:13:30   2022-09-25 20:13:30
# 3 2022-07-07 12:59:32   2022-07-07 12:59:32
# 4 2024-05-01 17:00:28   2024-05-01 17:00:28
# Error saat menerjemahkan: Tempat luas. Ada permainan anak juga menu menu nya enak dan harga paling murah.. Karyawan ramah ramah, _ssl.c:983: The handshake operation timed out
# Dataset setelah terjemahan:
#                                              snippet  \
# 0                                                 Ok
# 1                                             Nice 🤗
# 2                              very friendly service
# 3                                        Very good♥️
# 4  Harga lmyan terjangkau, tempatnya bersih ada p...
#
#                                           snippet_en
# 0                                                 Ok
# 1                                             Nice 🤗
# 2                              very friendly service
# 3                                      Very Good ♥ ️
# 4  The price of LMYAN is affordable, the place is...

# %% [markdown]
# ##01.a Examine the data

# %%
data
# Out:
#                   Source.Name           user_name  rating  \
# 0           reviews_bogo.xlsx       Lucky Rivanto       5
# 1           reviews_bogo.xlsx  Novita Catur putri       5
# 2           reviews_bogo.xlsx       aditiya risky       5
# 3           reviews_bogo.xlsx          Fita Julia       5
# 4           reviews_bogo.xlsx      M.choirul arif       5
# ...                       ...                 ...     ...
# 1025  reviews_warujayeng.xlsx       novia Bima873       4
# 1026  reviews_warujayeng.xlsx        anam syafiil       5
# 1027  reviews_warujayeng.xlsx        Septian Tian       5
# 1031  reviews_warujayeng.xlsx      Ahmad Sulaiman       5
# 1043  reviews_warujayeng.xlsx      Dewi Anggraini       5
#
#                                                 snippet          date  \
# 0                                                    Ok  7 months ago
# 1                                                Nice 🤗   2 years ago
# 2                                 very friendly service   2 years ago
# 3                                           Very good♥️   2 years ago
# 4     Harga lmyan terjangkau, tempatnya bersih ada p...  6 months ago
# ...                                                 ...           ...
# 1025                            Harga mumer dan terFav👌   2 years ago
# 1026                                        Mantab Jaya    a year ago
# 1027                                              Bagus   2 years ago
# 1031                                      Masoookk dekk   2 years ago
# 1043  Tempatnya nyaman, bersih, luas, makanannya jug...    5 days ago
#
#                 iso_date iso_date_of_last_edit  \
# 0    2024-03-18 09:57:31   2024-03-18 09:57:31
# 1    2022-07-07 11:04:13   2022-07-07 11:04:13
# 2    2022-09-25 20:13:30   2022-09-25 20:13:30
# 3    2022-07-07 12:59:32   2022-07-07 12:59:32
# 4    2024-05-01 17:00:28   2024-05-01 17:00:28
# ...                  ...                   ...
# 1025 2022-10-24 09:48:00   2022-10-24 09:48:00
# 1026 2023-06-19 22:49:36   2023-06-19 22:49:36
# 1027 2022-10-23 14:09:20   2022-10-23 14:09:20
# 1031 2022-08-23 14:19:56   2022-08-23 14:19:56
# 1043 2024-11-03 13:09:57   2024-11-03 13:43:08
#
#                                              snippet_en
# 0                                                    Ok
# 1                                                Nice 🤗
# 2                                 very friendly service
# 3                                         Very Good ♥ ️
# 4     The price of LMYAN is affordable, the place is...
# ...                                                 ...
# 1025                     MUMER AND Most Favorite Prices
# 1026                                        Mantab Jaya
# 1027                                               Good
# 1031                                      Masoookk Dekk
# 1043  The place is comfortable, clean, spacious, the...
#
# [762 rows x 8 columns]

# %%
data = data.dropna() #fast way to drop all null data
print(data.head())
# Out:
#          Source.Name           user_name  rating  \
# 0  reviews_bogo.xlsx       Lucky Rivanto       5
# 1  reviews_bogo.xlsx  Novita Catur putri       5
# 2  reviews_bogo.xlsx       aditiya risky       5
# 3  reviews_bogo.xlsx          Fita Julia       5
# 4  reviews_bogo.xlsx      M.choirul arif       5
#
#                                              snippet          date  \
# 0                                                 Ok  7 months ago
# 1                                             Nice 🤗   2 years ago
# 2                              very friendly service   2 years ago
# 3                                        Very good♥️   2 years ago
# 4  Harga lmyan terjangkau, tempatnya bersih ada p...  6 months ago
#
#              iso_date iso_date_of_last_edit
# 0 2024-03-18 09:57:31   2024-03-18 09:57:31
# 1 2022-07-07 11:04:13   2022-07-07 11:04:13
# 2 2022-09-25 20:13:30   2022-09-25 20:13:30
# 3 2022-07-07 12:59:32   2022-07-07 12:59:32
# 4 2024-05-01 17:00:28   2024-05-01 17:00:28

# %% [markdown]
# #02. Use SentimentIntensityAnalyzer

# %%
sentiments = SentimentIntensityAnalyzer()
data["Positive"] = [sentiments.polarity_scores(i)["pos"] for i in data["snippet_en"]]
data["Negative"] = [sentiments.polarity_scores(i)["neg"] for i in data["snippet_en"]]
data["Neutral"] = [sentiments.polarity_scores(i)["neu"] for i in data["snippet_en"]]
data['Compound'] = [sentiments.polarity_scores(i)["compound"] for i in data["snippet_en"]]
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_19672\4260308682.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Positive"] = [sentiments.polarity_scores(i)["pos"] for i in data["snippet"]]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_19672\4260308682.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Negative"] = [sentiments.polarity_scores(i)["neg"] for i in data["snippet"]]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_19672\4260308682.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Neutral"] = [sentiments.polarity_scores(i)["neu"] for i in data["snippet"]]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_19672\4260308682.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Compound'] = [sentiments.polarity_scores(i)["compound"] for i in data["snippet"]]

# %% [markdown]
# ##02.a Check the data output

# %%
data
# Out:
#                   Source.Name           user_name  rating  \
# 0           reviews_bogo.xlsx       Lucky Rivanto       5
# 1           reviews_bogo.xlsx  Novita Catur putri       5
# 2           reviews_bogo.xlsx       aditiya risky       5
# 3           reviews_bogo.xlsx          Fita Julia       5
# 4           reviews_bogo.xlsx      M.choirul arif       5
# ...                       ...                 ...     ...
# 1025  reviews_warujayeng.xlsx       novia Bima873       4
# 1026  reviews_warujayeng.xlsx        anam syafiil       5
# 1027  reviews_warujayeng.xlsx        Septian Tian       5
# 1031  reviews_warujayeng.xlsx      Ahmad Sulaiman       5
# 1043  reviews_warujayeng.xlsx      Dewi Anggraini       5
#
#                                                 snippet          date  \
# 0                                                    Ok  7 months ago
# 1                                                Nice 🤗   2 years ago
# 2                                 very friendly service   2 years ago
# 3                                           Very good♥️   2 years ago
# 4     Harga lmyan terjangkau, tempatnya bersih ada p...  6 months ago
# ...                                                 ...           ...
# 1025                            Harga mumer dan terFav👌   2 years ago
# 1026                                        Mantab Jaya    a year ago
# 1027                                              Bagus   2 years ago
# 1031                                      Masoookk dekk   2 years ago
# 1043  Tempatnya nyaman, bersih, luas, makanannya jug...    5 days ago
#
#                 iso_date iso_date_of_last_edit  Positive  Negative  Neutral  \
# 0    2024-03-18 09:57:31   2024-03-18 09:57:31     1.000       0.0    0.000
# 1    2022-07-07 11:04:13   2022-07-07 11:04:13     1.000       0.0    0.000
# 2    2022-09-25 20:13:30   2022-09-25 20:13:30     0.636       0.0    0.364
# 3    2022-07-07 12:59:32   2022-07-07 12:59:32     0.000       0.0    1.000
# 4    2024-05-01 17:00:28   2024-05-01 17:00:28     0.000       0.0    1.000
# ...                  ...                   ...       ...       ...      ...
# 1025 2022-10-24 09:48:00   2022-10-24 09:48:00     0.000       0.0    1.000
# 1026 2023-06-19 22:49:36   2023-06-19 22:49:36     0.000       0.0    1.000
# 1027 2022-10-23 14:09:20   2022-10-23 14:09:20     0.000       0.0    1.000
# 1031 2022-08-23 14:19:56   2022-08-23 14:19:56     0.000       0.0    1.000
# 1043 2024-11-03 13:09:57   2024-11-03 13:43:08     0.000       0.0    1.000
#
#       Compound
# 0       0.2960
# 1       0.4215
# 2       0.5413
# 3       0.0000
# 4       0.0000
# ...        ...
# 1025    0.0000
# 1026    0.0000
# 1027    0.0000
# 1031    0.0000
# 1043    0.0000
#
# [762 rows x 11 columns]

# %% [markdown]
# #03. Make the Sentiment value based on compound score

# %%
score = data["Compound"].values
sentiment = []
for i in score:
    if i >= 0.05 :
        sentiment.append('Positive')
    elif i <= -0.05 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
data["Sentiment"] = sentiment
data
# Out:
#                                                   Review  Positive  Negative  \
# 0      nice hotel expensive parking got good deal sta...     0.285     0.072
# 1      ok nothing special charge diamond member hilto...     0.189     0.110
# 2      nice rooms not 4* experience hotel monaco seat...     0.219     0.081
# 3      unique, great stay, wonderful time hotel monac...     0.385     0.060
# 4      great stay great stay, went seahawk game aweso...     0.221     0.135
# ...                                                  ...       ...       ...
# 20486  best kept secret 3rd time staying charm, not 5...     0.272     0.063
# 20487  great location price view hotel great quick pl...     0.430     0.000
# 20488  ok just looks nice modern outside, desk staff ...     0.145     0.131
# 20489  hotel theft ruined vacation hotel opened sept ...     0.179     0.150
# 20490  people talking, ca n't believe excellent ratin...     0.140     0.193
#
#        Neutral  Compound Sentiment
# 0        0.643    0.9747  Positive
# 1        0.701    0.9787  Positive
# 2        0.700    0.9889  Positive
# 3        0.555    0.9912  Positive
# 4        0.643    0.9797  Positive
# ...        ...       ...       ...
# 20486    0.665    0.9834  Positive
# 20487    0.570    0.9753  Positive
# 20488    0.724    0.2629  Positive
# 20489    0.671    0.9867  Positive
# 20490    0.668   -0.6071  Negative
#
# [20491 rows x 6 columns]

# %% [markdown]
# ##02.a Count how many sentiment is ready

# %%
print(data["Sentiment"].value_counts())
# Out:
# Positive    18831
# Negative     1569
# Neutral        91
# Name: Sentiment, dtype: int64

# %% [markdown]
# #Conclusion
#
# We can use the compound score to make predictions and label the original dataset. This step is crucial in creating training data.
